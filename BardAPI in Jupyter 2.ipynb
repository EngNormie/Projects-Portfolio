# %% [markdown]
# # Using Google Bard in Jupyter Notebook Google
# Bard, a Large Language Model (LLM) by Google AI can be accessed in Jupyter Notebooks through the Bard-API Python package.
# Follow the steps below to start interacting with Bard in your jupyter notebooks;

# %% [markdown]
# ## 1. Visit Google Bard Site
# * Launch the [Google Bard Site](https://bard.google.com/)

# %% [markdown]
# ![Google%20Bard.png](attachment:Google%20Bard.png)

# %% [markdown]
# * Sign in to start using Bard

# %% [markdown]
# * Obtain BARD_API_KEY:
#     - Whilest signed-in in Bard website, press **F12** to launch console
#     - Select the **Application** tab and select the **Cookies** from the Storage menu drop-down. In the Cookies, select the **accounts** and try to find the **__Secure-1PSID** and copy the values that display underneath - yellow shade in the image below. Keep your __Secure-1PSID somewhere secure, you'll need it in step 3.

# %% [markdown]
# ![Get%20BardAPI%20Key.png](attachment:Get%20BardAPI%20Key.png)

# %% [markdown]
# ## 2. Intall the Bard-API package
# If your python environment has no bardapi package, install it using the code below;

# %% [raw]
# pip install bardapi

# %% [markdown]
# ## 3. Set the *__Secure-1PSID* into the Bard-API environment.
# Use the following code to set the __Secure-1PSID for your BARD_API_KEY.

# %% [raw]
# from bardapi import Bard
# import os
#
# #Use your __Secure-1PSID value (copied from step 1) in place of XXXX
# os.environ['_BARD_API_KEY']="XXXX"

# %% [markdown]
# To address errors caused by delayed responses in environments like Google Colab and containers, utilize the timeout argument as shown below;

# %% [raw]
# bard = Bard(timeout=30) # Set timeout in seconds

# %% [markdown]
# ## 4. Access the Google Bard in your environment through the following code.

# %% [raw]
# # set your input text
# input_text = "what is AI?"
#
# print(Bard().get_answer(input_text)['content'])

# %% [markdown]
# ![BardAPI%20in%20Jupyter.png](attachment:BardAPI%20in%20Jupyter.png)

# %% [markdown]
# # Conclusion
# There are many use cases of Bard.
#
# 💪 Supports a wide range of tasks, including:
#
# 🗣 Text generation
#
# 🔁 Translation
#
# ❓️&🅰️ Question answering
#
# Explore more on writing quality prompts in order to gain much from Bard and other LLM APIs.
